# %% [markdown]
# MEMBUAT NODE

# %%
class Node:
  def __init__ (self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

print (n1.dataval)
print (n2.dataval)
print (n3.dataval)
# Out:
# Januari
# Februari
# Maret

# %% [markdown]
# MEMBUAT CLASS LINKED LIST

# %%
class LinkedList:
  def __init__(self):
    self.headval = None

Li = LinkedList()
Li.headval = n1

# Link ke n2
Li.headval.nextval = n2

# Link ke n3
n2.nextval = n3

# %% [markdown]
# MENELUSURI LINKED LIST

# %%
class Node:
  def __init__ (self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

Li = LinkedList()
Li.headval = n1

# Link ke n2
Li.headval.nextval = n2

# Link ke n3
n2.nextval = n3

Li.listprint()
# Out:
# Januari
# Februari
# Maret

# %% [markdown]
# PENYISIPAN DI AWAL

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
  def __init__(self):
    self.headval = None

  # print linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

  # membuat atribut begining untuk update node baru
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
    NewNode.nextval = self.headval
    self.headval = NewNode

Li = LinkedList()
Li.headval = n1

# Link node pertama ke node kedua
Li.headval.nextval = n2

# Link node ke 2 ke node ketiga
n2.nextval = n3

Li.AddBegining("Desember")
Li.listprint()
# Out:
# Desember
# Januari
# Februari
# Maret

# %% [markdown]
# PENYISIPAN DITENGAH

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
  def __init__(self):
    self.headval = None

  # print linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

  # membuat fungsi add in between di tengah
  def AddInBetween(self, mid_node, newdata):
    if mid_node is None:
      print("The mentioned node is absent")
      return
    NewNode = Node(newdata)
    NewNode.nextval = mid_node.nextval
    mid_node.nextval = NewNode

Li = LinkedList()
Li.headval = n1

# Link node pertama ke node kedua
Li.headval.nextval = n2

# Link node ke 2 ke node ketiga
n2.nextval = n3

# nambahin nide sesudah n1
Li.AddInBetween(n1,"Desember")
Li.listprint()
# Out:
# Januari
# Desember
# Februari
# Maret

# %% [markdown]
# PENYISIPAN DIAKHIR

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
  def __init__(self):
    self.headval = None

  # print linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

  # membuat fungsi add in between di tengah
  def AddInEnd(self, newdata):
    NewNode = Node(newdata)
    if self.headval is None:
      self.headval = NewNode
      return
    last = self.headval
    while(last.nextval):
      last = last.nextval
    last.nextval = NewNode

Li = LinkedList()
Li.headval = n1

# Link node pertama ke node kedua
Li.headval.nextval = n2

# Link node ke 2 ke node ketiga
n2.nextval = n3

# nambahin nide sesudah n1
Li.AddInEnd("Desember")
Li.listprint()
# Out:
# Januari
# Februari
# Maret
# Desember

# %% [markdown]
# HAPUS NODE

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

  # print linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

  # membuat atribut begining untuk update node baru
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
  # Upddate node baru ke val
    NewNode.nextval = self.headval
    self.headval = NewNode
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
  def __init__(self):
    self.headval = None

  # print linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print(printval.dataval)
      printval = printval.nextval

  # membuat atribut begining untuk update node baru
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
    NewNode.nextval = self.headval
    self.headval = NewNode

  # Function to remove node by key
  def RemoveNode(self, Removekey):
    HeadVal = self.headval
    if (HeadVal is not None):
      if (HeadVal.dataval == Removekey):
        self.headval = HeadVal.next
        HeadVal = None
        return
    while (HeadVal is not None):
      if HeadVal.dataval == Removekey:
        break
      prev = HeadVal
      HeadVal = HeadVal.nextval
    if (HeadVal == None):
      return
    prev.nextval = HeadVal.nextval
    HeadVal = None

# create linked list named Li
Li = LinkedList()

# add node
Li.AddBegining("April")
Li.AddBegining("Maret")
Li.AddBegining("Febuari")
print("Sebelum dilakukan remove")
Li.listprint()
print("="*50)

# remove node by key = "Maret"
Li.RemoveNode("Maret")
print("Setelah dilakukan remove dengan kunci 'Maret'")
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Febuari
# Maret
# April
# ...
# Setelah dilakukan remove dengan kunci 'Maret'
# Febuari
# April

# %% [markdown]
# Hapus Node di awal

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    # Menampilkan linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Menambah node di awal
    def AddBegining(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

    # HAPUS NODE DI AWAL
    def RemoveBegin(self):
        # Cek apakah linked list kosong
        if self.headval is None:
            print("Linked list kosong, tidak ada yang dihapus")
            return

        # Simpan node yang akan dihapus untuk ditampilkan
        removed_node = self.headval
        # Head dipindah ke node berikutnya
        self.headval = self.headval.nextval
        print(f"Node '{removed_node.dataval}' berhasil dihapus dari awal")

# Membuat linked list
Li = LinkedList()

# Menambahkan node (urutan terbalik karena AddBegining)
Li.AddBegining("Maret")
Li.AddBegining("Februari")
Li.AddBegining("Januari")

print("Linked List AWAL:")
Li.listprint()
print("=" * 50)

# Hapus node di awal
Li.RemoveBegin()

print("\nLinked List SETELAH hapus node di awal:")
Li.listprint()
# Out:
# Linked List AWAL:
# Januari
# Februari
# Maret
# ...
# Node 'Januari' berhasil dihapus dari awal
#
# Linked List SETELAH hapus node di awal:
# Februari
# Maret

# %% [markdown]
# Hapus Node di Tengah

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    # Menampilkan linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Menambah node di awal
    def AddBegining(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

    # HAPUS NODE BERDASARKAN KATA KUNCI (di tengah)
    def RemoveNode(self, Removekey):
        HeadVal = self.headval

        # Cek apakah linked list kosong
        if HeadVal is None:
            print("Linked list kosong")
            return

        # Kasus 1: Node yang akan dihapus adalah HEAD
        if (HeadVal.dataval == Removekey):
            self.headval = HeadVal.nextval
            print(f"Node HEAD dengan nilai '{Removekey}' berhasil dihapus")
            HeadVal = None
            return

        # Kasus 2: Node yang akan dihapus ada di TENGAH atau AKHIR
        while (HeadVal is not None):
            if HeadVal.dataval == Removekey:
                break
            prev = HeadVal
            HeadVal = HeadVal.nextval

        # Jika kata kunci tidak ditemukan
        if (HeadVal == None):
            print(f"Node dengan nilai '{Removekey}' tidak ditemukan")
            return

        # Hapus node yang ditemukan
        prev.nextval = HeadVal.nextval
        print(f"Node dengan nilai '{Removekey}' berhasil dihapus")
        HeadVal = None

# Membuat linked list
Li = LinkedList()

# Menambahkan node
Li.AddBegining("Mei")
Li.AddBegining("April")
Li.AddBegining("Maret")
Li.AddBegining("Februari")
Li.AddBegining("Januari")

print("Linked List AWAL:")
Li.listprint()
print("=" * 50)

# Hapus node di tengah (contoh: hapus "Maret")
Li.RemoveNode("Maret")

print("\nLinked List SETELAH hapus node 'Maret':")
Li.listprint()
# Out:
# Linked List AWAL:
# Januari
# Februari
# Maret
# April
# Mei
# ...
# Node dengan nilai 'Maret' berhasil dihapus
#
# Linked List SETELAH hapus node 'Maret':
# Januari
# Februari
# April
# Mei

# %% [markdown]
# Hapus Node di akhir

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    # Menampilkan linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Menambah node di awal
    def AddBegining(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

    # HAPUS NODE DI AKHIR
    def RemoveEnd(self):
        # Cek apakah linked list kosong
        if self.headval is None:
            print("Linked list kosong, tidak ada yang dihapus")
            return

        # Kasus 1: Hanya ada 1 node
        if self.headval.nextval is None:
            removed = self.headval
            self.headval = None
            print(f"Node '{removed.dataval}' (satu-satunya node) berhasil dihapus")
            return

        # Kasus 2: Ada lebih dari 1 node
        second_last = self.headval
        # Cari node sebelum node terakhir
        while(second_last.nextval.nextval):
            second_last = second_last.nextval

        # Simpan node terakhir untuk ditampilkan
        removed = second_last.nextval
        # Hapus node terakhir
        second_last.nextval = None
        print(f"Node akhir '{removed.dataval}' berhasil dihapus")

# Membuat linked list
Li = LinkedList()

# Menambahkan node
Li.AddBegining("Jumat")
Li.AddBegining("Kamis")
Li.AddBegining("Rabu")
Li.AddBegining("Selasa")
Li.AddBegining("Senin")

print("Linked List AWAL:")
Li.listprint()
print("=" * 50)

# Hapus node di akhir
Li.RemoveEnd()

print("\nLinked List SETELAH hapus node di akhir:")
Li.listprint()
# Out:
# Linked List AWAL:
# Senin
# Selasa
# Rabu
# Kamis
# Jumat
# ...
# Node akhir 'Jumat' berhasil dihapus
#
# Linked List SETELAH hapus node di akhir:
# Senin
# Selasa
# Rabu
# Kamis

# %% [markdown]
# Latsol 1

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
        self.prevval = None  # Pointer ke node sebelumnya (khusus double linked list)

class DoubleLinkedList:
    def __init__(self):
        self.headval = None

    # Menampilkan double linked list dari depan ke belakang
    def listprint_forward(self):
        printval = self.headval
        print("Penelusuran maju (head -> tail):")
        while printval is not None:
            print(printval.dataval, end=" <-> ")
            printval = printval.nextval
        print("None")

    # Menampilkan double linked list dari belakang ke depan
    def listprint_backward(self):
        # Cari node terakhir dulu
        last = self.headval
        while last.nextval is not None:
            last = last.nextval

        print("Penelusuran mundur (tail -> head):")
        while last is not None:
            print(last.dataval, end=" <-> ")
            last = last.prevval
        print("None")

    # Menambah node di akhir
    def AddEnd(self, newdata):
        NewNode = Node(newdata)

        # Jika linked list kosong
        if self.headval is None:
            self.headval = NewNode
            return

        # Cari node terakhir
        last = self.headval
        while last.nextval is not None:
            last = last.nextval

        # Hubungkan node baru
        last.nextval = NewNode
        NewNode.prevval = last

    # Penyisipan di TENGAH (setelah node dengan nilai tertentu)
    def InsertAfter(self, key, newdata):
        # Cari node dengan nilai key
        current = self.headval
        while current is not None:
            if current.dataval == key:
                break
            current = current.nextval

        # Jika key tidak ditemukan
        if current is None:
            print(f"Node dengan nilai '{key}' tidak ditemukan")
            return

        # Buat node baru
        NewNode = Node(newdata)

        # Hubungkan node baru dengan node setelahnya
        NewNode.nextval = current.nextval
        NewNode.prevval = current

        # Hubungkan node setelahnya dengan node baru (jika ada)
        if current.nextval is not None:
            current.nextval.prevval = NewNode

        # Hubungkan node saat ini dengan node baru
        current.nextval = NewNode

        print(f"Node '{newdata}' berhasil disisipkan setelah node '{key}'")

    # Hapus node dengan kata kunci
    def RemoveNode(self, key):
        current = self.headval

        # Cek apakah linked list kosong
        if current is None:
            print("Linked list kosong")
            return

        # Cari node dengan nilai key
        while current is not None:
            if current.dataval == key:
                break
            current = current.nextval

        # Jika key tidak ditemukan
        if current is None:
            print(f"Node dengan nilai '{key}' tidak ditemukan")
            return

        # Kasus 1: Node yang dihapus adalah HEAD
        if current.prevval is None:
            self.headval = current.nextval
            if self.headval is not None:
                self.headval.prevval = None
            print(f"Node HEAD '{key}' berhasil dihapus")

        # Kasus 2: Node yang dihapus adalah TAIL
        elif current.nextval is None:
            current.prevval.nextval = None
            print(f"Node TAIL '{key}' berhasil dihapus")

        # Kasus 3: Node yang dihapus ada di TENGAH
        else:
            current.prevval.nextval = current.nextval
            current.nextval.prevval = current.prevval
            print(f"Node TENGAH '{key}' berhasil dihapus")

        current = None

# ============================================
# IMPLEMENTASI SOAL 1
# ============================================
print("=" * 50)
print("SOAL 1: DOUBLE LINKED LIST")
print("=" * 50)

# Membuat double linked list dengan 3 node
dll = DoubleLinkedList()

# Menambahkan 3 node awal
dll.AddEnd("Node 1 (Awal)")
dll.AddEnd("Node 2 (Awal)")
dll.AddEnd("Node 3 (Awal)")

print("\n🔹 Double Linked List AWAL (3 node):")
dll.listprint_forward()
dll.listprint_backward()
print("-" * 40)

# ============================================
# PENYISIPAN TENGAH
# ============================================
print("\n🔸 PENYISIPAN TENGAH:")
print("Menyisipkan 'Node Baru (Tengah)' setelah 'Node 2 (Awal)'")
dll.InsertAfter("Node 2 (Awal)", "Node Baru (Tengah)")

print("\n✅ Hasil setelah PENYISIPAN TENGAH:")
dll.listprint_forward()
dll.listprint_backward()
print("-" * 40)

# ============================================
# HAPUS DENGAN KATA KUNCI
# ============================================
print("\n🔸 HAPUS DENGAN KATA KUNCI:")
print("Menghapus node dengan nilai 'Node 2 (Awal)'")
dll.RemoveNode("Node 2 (Awal)")

print("\n✅ Hasil setelah PENGHAPUSAN:")
dll.listprint_forward()
dll.listprint_backward()
# Out:
# ...
# SOAL 1: DOUBLE LINKED LIST
# ...
#
# 🔹 Double Linked List AWAL (3 node):
# Penelusuran maju (head -> tail):
# Node 1 (Awal) <-> Node 2 (Awal) <-> Node 3 (Awal) <-> None
# Penelusuran mundur (tail -> head):
# Node 3 (Awal) <-> Node 2 (Awal) <-> Node 1 (Awal) <-> None
# ----------------------------------------
#
# 🔸 PENYISIPAN TENGAH:
# Menyisipkan 'Node Baru (Tengah)' setelah 'Node 2 (Awal)'
# Node 'Node Baru (Tengah)' berhasil disisipkan setelah node 'Node 2 (Awal)'
#
# ✅ Hasil setelah PENYISIPAN TENGAH:
# Penelusuran maju (head -> tail):
# Node 1 (Awal) <-> Node 2 (Awal) <-> Node Baru (Tengah) <-> Node 3 (Awal) <-> None
# Penelusuran mundur (tail -> head):
# Node 3 (Awal) <-> Node Baru (Tengah) <-> Node 2 (Awal) <-> Node 1 (Awal) <-> None
# ----------------------------------------
#
# 🔸 HAPUS DENGAN KATA KUNCI:
# Menghapus node dengan nilai 'Node 2 (Awal)'
# Node TENGAH 'Node 2 (Awal)' berhasil dihapus
#
# ✅ Hasil setelah PENGHAPUSAN:
# Penelusuran maju (head -> tail):
# ...

# %% [markdown]
# SOAL 1: Double Linked List dengan 3 Node

# %%
# buat node
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None
        self.prevval = None  # Pointer ke node sebelumnya

class DoubleLinkedList:
    def __init__(self):
        self.headval = None

    # Menampilkan double linked list dari depan ke belakang
    def listprint_forward(self):
        printval = self.headval
        print("Penelusuran maju (head -> tail):")
        while printval is not None:
            print(printval.dataval, end=" <-> ")
            printval = printval.nextval
        print("None")

    # Menampilkan double linked list dari belakang ke depan
    def listprint_backward(self):
        # Cari node terakhir dulu
        last = self.headval
        if last is None:
            print("Penelusuran mundur (tail -> head):")
            print("None")
            return
        while last.nextval is not None:
            last = last.nextval

        print("Penelusuran mundur (tail -> head):")
        while last is not None:
            print(last.dataval, end=" <-> ")
            last = last.prevval
        print("None")

    # Menambah node di akhir
    def AddEnd(self, newdata):
        NewNode = Node(newdata)

        # Jika linked list kosong
        if self.headval is None:
            self.headval = NewNode
            return

        # Cari node terakhir
        last = self.headval
        while last.nextval is not None:
            last = last.nextval

        # Hubungkan node baru
        last.nextval = NewNode
        NewNode.prevval = last

    # Penyisipan di TENGAH (setelah node dengan nilai tertentu)
    def InsertAfter(self, key, newdata):
        # Cari node dengan nilai key
        current = self.headval
        while current is not None:
            if current.dataval == key:
                break
            current = current.nextval

        # Jika key tidak ditemukan
        if current is None:
            print(f"Node dengan nilai '{key}' tidak ditemukan")
            return

        # Buat node baru
        NewNode = Node(newdata)

        # Hubungkan node baru dengan node setelahnya
        NewNode.nextval = current.nextval
        NewNode.prevval = current

        # Hubungkan node setelahnya dengan node baru (jika ada)
        if current.nextval is not None:
            current.nextval.prevval = NewNode

        # Hubungkan node saat ini dengan node baru
        current.nextval = NewNode

        print(f"Node '{newdata}' berhasil disisipkan setelah node '{key}'")

    # Hapus node dengan kata kunci
    def RemoveNode(self, key):
        current = self.headval

        # Cek apakah linked list kosong
        if current is None:
            print("Linked list kosong")
            return

        # Cari node dengan nilai key
        while current is not None:
            if current.dataval == key:
                break
            current = current.nextval

        # Jika key tidak ditemukan
        if current is None:
            print(f"Node dengan nilai '{key}' tidak ditemukan")
            return

        # Kasus 1: Node yang dihapus adalah HEAD
        if current.prevval is None:
            self.headval = current.nextval
            if self.headval is not None:
                self.headval.prevval = None
            print(f"Node HEAD '{key}' berhasil dihapus")

        # Kasus 2: Node yang dihapus adalah TAIL
        elif current.nextval is None:
            current.prevval.nextval = None
            print(f"Node TAIL '{key}' berhasil dihapus")

        # Kasus 3: Node yang dihapus ada di TENGAH
        else:
            current.prevval.nextval = current.nextval
            current.nextval.prevval = current.prevval
            print(f"Node TENGAH '{key}' berhasil dihapus")

        current = None
# soal
print("=" * 50)
print("SOAL 1: DOUBLE LINKED LIST")
print("=" * 50)

# Membuat double linked list dengan 3 node
dll = DoubleLinkedList()

# Menambahkan 3 node awal
dll.AddEnd("Node 1 (Awal)")
dll.AddEnd("Node 2 (Awal)")
dll.AddEnd("Node 3 (Awal)")

print("\nDouble Linked List AWAL (3 node):")
dll.listprint_forward()
dll.listprint_backward()
print("-" * 40)

# PENYISIPAN TENGAH
print("\nPENYISIPAN TENGAH:")
print("Menyisipkan 'Node Baru (Tengah)' setelah 'Node 2 (Awal)'")
dll.InsertAfter("Node 2 (Awal)", "Node Baru (Tengah)")

print("\nHasil setelah PENYISIPAN TENGAH:")
dll.listprint_forward()
dll.listprint_backward()
print("-" * 40)
# Out:
# ...
# SOAL 1: DOUBLE LINKED LIST
# ...
#
# Double Linked List AWAL (3 node):
# Penelusuran maju (head -> tail):
# Node 1 (Awal) <-> Node 2 (Awal) <-> Node 3 (Awal) <-> None
# Penelusuran mundur (tail -> head):
# Node 3 (Awal) <-> Node 2 (Awal) <-> Node 1 (Awal) <-> None
# ----------------------------------------
#
# PENYISIPAN TENGAH:
# Menyisipkan 'Node Baru (Tengah)' setelah 'Node 2 (Awal)'
# Node 'Node Baru (Tengah)' berhasil disisipkan setelah node 'Node 2 (Awal)'
#
# Hasil setelah PENYISIPAN TENGAH:
# Penelusuran maju (head -> tail):
# Node 1 (Awal) <-> Node 2 (Awal) <-> Node Baru (Tengah) <-> Node 3 (Awal) <-> None
# Penelusuran mundur (tail -> head):
# Node 3 (Awal) <-> Node Baru (Tengah) <-> Node 2 (Awal) <-> Node 1 (Awal) <-> None
# ----------------------------------------

# %% [markdown]
# SOAL 2: Circular Linked List dengan 3 Node

# %%
# Buat node
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class CircularLinkedList:
    def __init__(self):
        self.headval = None

    # Method to add a node to an empty list or at the end of a circular list
    def add_to_end(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            NewNode.nextval = self.headval # Point to itself for circularity
        else:
            current = self.headval
            while current.nextval != self.headval:
                current = current.nextval
            current.nextval = NewNode
            NewNode.nextval = self.headval # New node points back to head

    # Method to print the circular linked list
    def listprint(self):
        if self.headval is None:
            print("Circular Linked List kosong")
            return

        printval = self.headval
        print("Penelusuran Circular Linked List (mulai dari head):")
        while True:
            print(printval.dataval, end=" -> ")
            printval = printval.nextval
            if printval == self.headval:
                break
        print(self.headval.dataval, "(kembali ke head)") # Indicate circularity


# IMPLEMENTASI SOAL 2
print("=" * 50)
print("SOAL 2: CIRCULAR LINKED LIST")
print("=" * 50)

# Membuat circular linked list dengan 3 node
cll = CircularLinkedList()

# Menambahkan 3 node awal
cll.add_to_end("Node A")
cll.add_to_end("Node B")
cll.add_to_end("Node C")

print("\nCircular Linked List AWAL (3 node):")
cll.listprint()
print("-" * 40)

# Contoh menambahkan node keempat
print("\nMenambahkan 'Node D' ke akhir list")
cll.add_to_end("Node D")

print("\nHasil setelah penambahan 'Node D':")
cll.listprint()
print("-" * 40)
# Out:
# ...
# SOAL 2: CIRCULAR LINKED LIST
# ...
#
# Circular Linked List AWAL (3 node):
# Penelusuran Circular Linked List (mulai dari head):
# Node A -> Node B -> Node C -> Node A (kembali ke head)
# ----------------------------------------
#
# Menambahkan 'Node D' ke akhir list
#
# Hasil setelah penambahan 'Node D':
# Penelusuran Circular Linked List (mulai dari head):
# Node A -> Node B -> Node C -> Node D -> Node A (kembali ke head)
# ----------------------------------------
